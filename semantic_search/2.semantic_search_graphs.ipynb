# %% [markdown]
# ### References - Recommender w/ NLP and Graphs
#
# 1. [Building a Strong Baseline Recommender in PyTorch, on a Laptop](https://eugeneyan.com/writing/recommender-systems-baseline-pytorch/)
# 2. [Beating the Baseline Recommender with Graph & NLP in Pytorch](https://eugeneyan.com/writing/recommender-systems-graph-and-nlp-pytorch/)

# %%
import argparse
import datetime

import numpy as np
import pandas as pd
import torch
from sklearn.metrics import roc_auc_score
from torch import optim
from torch.utils.data import DataLoader

# %%
from parse_json import parse_json_to_df

# %%
shuffle = True
emb_dim = 128
epochs = 5
initial_lr = 0.01

# %%
# !ls -lah data/
# Out:
# total 22383064
# drwxr-xr-x   5 rsilvei  813930708   160B Jun 25 13:59 .
# drwxr-xr-x  11 rsilvei  813930708   352B Jun 25 14:04 ..
# -rw-r--r--   1 rsilvei  813930708   8.8G Jun 10 19:01 reviews_Books_5.json
# -rw-r--r--   1 rsilvei  813930708   1.4G Jun 10 18:37 reviews_Electronics_5.json
# -rw-r--r--@  1 rsilvei  813930708   473M Jun 25 13:59 reviews_Electronics_5.json.gz

# %%
#electronics_path = "data/reviews_Electronics_5.json.gz"
#electronics_csv = "data/electronics.csv"
books_path = "data/reviews_Books_5.json.gz"
books_csv = "data/books.csv"

# %%
df = parse_json_to_df(books_path)
# Out:
# 2021-06-25 14:25:21,431 - Rows processed: 10,000
# 2021-06-25 14:25:22,132 - Rows processed: 20,000
# 2021-06-25 14:25:23,031 - Rows processed: 30,000
# 2021-06-25 14:25:23,635 - Rows processed: 40,000
# 2021-06-25 14:25:24,428 - Rows processed: 50,000
# 2021-06-25 14:25:25,208 - Rows processed: 60,000
# 2021-06-25 14:25:26,375 - Rows processed: 70,000
# 2021-06-25 14:25:27,092 - Rows processed: 80,000
# 2021-06-25 14:25:28,437 - Rows processed: 90,000
# 2021-06-25 14:25:29,002 - Rows processed: 100,000
# 2021-06-25 14:25:29,541 - Rows processed: 110,000
# 2021-06-25 14:25:30,043 - Rows processed: 120,000
# 2021-06-25 14:25:30,669 - Rows processed: 130,000
# 2021-06-25 14:25:31,239 - Rows processed: 140,000
# 2021-06-25 14:25:31,718 - Rows processed: 150,000
# 2021-06-25 14:25:32,212 - Rows processed: 160,000
# 2021-06-25 14:25:32,746 - Rows processed: 170,000
# 2021-06-25 14:25:33,376 - Rows processed: 180,000
# 2021-06-25 14:25:33,884 - Rows processed: 190,000
# 2021-06-25 14:25:34,443 - Rows processed: 200,000
# 2021-06-25 14:25:34,922 - Rows processed: 210,000
# 2021-06-25 14:25:35,414 - Rows processed: 220,000
# 2021-06-25 14:25:35,906 - Rows processed: 230,000
# 2021-06-25 14:25:36,547 - Rows processed: 240,000
# 2021-06-25 14:25:37,251 - Rows processed: 250,000
# 2021-06-25 14:25:37,862 - Rows processed: 260,000
# 2021-06-25 14:25:38,436 - Rows processed: 270,000
# 2021-06-25 14:25:39,026 - Rows processed: 280,000
# 2021-06-25 14:25:39,612 - Rows processed: 290,000
# 2021-06-25 14:25:40,208 - Rows processed: 300,000
# 2021-06-25 14:25:40,795 - Rows processed: 310,000
# 2021-06-25 14:25:41,364 - Rows processed: 320,000
# 2021-06-25 14:25:42,112 - Rows processed: 330,000
# 2021-06-25 14:25:42,649 - Rows processed: 340,000
# 2021-06-25 14:25:43,193 - Rows processed: 350,000
# 2021-06-25 14:25:43,770 - Rows processed: 360,000
# 2021-06-25 14:25:44,412 - Rows processed: 370,000
# 2021-06-25 14:25:44,979 - Rows processed: 380,000
# 2021-06-25 14:25:45,520 - Rows processed: 390,000
# 2021-06-25 14:25:45,992 - Rows processed: 400,000
# 2021-06-25 14:25:46,491 - Rows processed: 410,000
# 2021-06-25 14:25:47,011 - Rows processed: 420,000
# 2021-06-25 14:25:47,702 - Rows processed: 430,000
# 2021-06-25 14:25:48,208 - Rows processed: 440,000
# 2021-06-25 14:25:48,665 - Rows processed: 450,000
# 2021-06-25 14:25:49,154 - Rows processed: 460,000
# 2021-06-25 14:25:49,598 - Rows processed: 470,000
# 2021-06-25 14:25:50,046 - Rows processed: 480,000
# 2021-06-25 14:25:50,499 - Rows processed: 490,000
# 2021-06-25 14:25:51,010 - Rows processed: 500,000
# 2021-06-25 14:25:51,494 - Rows processed: 510,000
# 2021-06-25 14:25:52,042 - Rows processed: 520,000
# 2021-06-25 14:25:52,549 - Rows processed: 530,000
# 2021-06-25 14:25:53,013 - Rows processed: 540,000
# 2021-06-25 14:25:53,801 - Rows processed: 550,000
# 2021-06-25 14:25:54,280 - Rows processed: 560,000
# 2021-06-25 14:25:54,809 - Rows processed: 570,000
# 2021-06-25 14:25:55,383 - Rows processed: 580,000
# 2021-06-25 14:25:55,975 - Rows processed: 590,000
# 2021-06-25 14:25:56,548 - Rows processed: 600,000
# 2021-06-25 14:25:57,093 - Rows processed: 610,000
# 2021-06-25 14:25:57,623 - Rows processed: 620,000
# 2021-06-25 14:25:58,129 - Rows processed: 630,000
# 2021-06-25 14:25:58,570 - Rows processed: 640,000
# 2021-06-25 14:25:59,000 - Rows processed: 650,000
# 2021-06-25 14:25:59,442 - Rows processed: 660,000
# 2021-06-25 14:25:59,928 - Rows processed: 670,000
# 2021-06-25 14:26:00,420 - Rows processed: 680,000
# 2021-06-25 14:26:00,878 - Rows processed: 690,000
# 2021-06-25 14:26:01,405 - Rows processed: 700,000
# 2021-06-25 14:26:02,264 - Rows processed: 710,000
# 2021-06-25 14:26:02,732 - Rows processed: 720,000
# 2021-06-25 14:26:03,261 - Rows processed: 730,000
# 2021-06-25 14:26:03,848 - Rows processed: 740,000
# 2021-06-25 14:26:04,359 - Rows processed: 750,000
# 2021-06-25 14:26:04,848 - Rows processed: 760,000
# 2021-06-25 14:26:05,279 - Rows processed: 770,000
# 2021-06-25 14:26:05,740 - Rows processed: 780,000
# 2021-06-25 14:26:06,221 - Rows processed: 790,000
# 2021-06-25 14:26:06,747 - Rows processed: 800,000
# 2021-06-25 14:26:58,407 - Rows processed: 1,780,000
# 2021-06-25 14:26:58,896 - Rows processed: 1,790,000
# 2021-06-25 14:26:59,307 - Rows processed: 1,800,000
# 2021-06-25 14:26:59,734 - Rows processed: 1,810,000
# 2021-06-25 14:27:00,123 - Rows processed: 1,820,000
# 2021-06-25 14:27:00,582 - Rows processed: 1,830,000
# 2021-06-25 14:27:02,048 - Rows processed: 1,840,000
# 2021-06-25 14:27:02,550 - Rows processed: 1,850,000
# 2021-06-25 14:27:03,067 - Rows processed: 1,860,000
# 2021-06-25 14:27:03,527 - Rows processed: 1,870,000
# 2021-06-25 14:27:04,012 - Rows processed: 1,880,000
# 2021-06-25 14:27:04,485 - Rows processed: 1,890,000
# 2021-06-25 14:27:04,956 - Rows processed: 1,900,000
# 2021-06-25 14:27:05,359 - Rows processed: 1,910,000
# 2021-06-25 14:27:05,820 - Rows processed: 1,920,000
# 2021-06-25 14:27:06,247 - Rows processed: 1,930,000
# 2021-06-25 14:27:06,661 - Rows processed: 1,940,000
# 2021-06-25 14:27:07,072 - Rows processed: 1,950,000
# 2021-06-25 14:27:07,520 - Rows processed: 1,960,000
# 2021-06-25 14:27:07,950 - Rows processed: 1,970,000
# 2021-06-25 14:27:08,393 - Rows processed: 1,980,000
# 2021-06-25 14:27:08,830 - Rows processed: 1,990,000
# 2021-06-25 14:27:09,294 - Rows processed: 2,000,000
# 2021-06-25 14:27:09,741 - Rows processed: 2,010,000
# 2021-06-25 14:27:10,170 - Rows processed: 2,020,000
# 2021-06-25 14:27:10,610 - Rows processed: 2,030,000
# 2021-06-25 14:27:11,098 - Rows processed: 2,040,000
# 2021-06-25 14:27:11,613 - Rows processed: 2,050,000
# 2021-06-25 14:27:12,130 - Rows processed: 2,060,000
# 2021-06-25 14:27:12,896 - Rows processed: 2,070,000
# 2021-06-25 14:27:13,494 - Rows processed: 2,080,000
# 2021-06-25 14:27:14,047 - Rows processed: 2,090,000
# 2021-06-25 14:27:14,692 - Rows processed: 2,100,000
# 2021-06-25 14:27:15,259 - Rows processed: 2,110,000
# 2021-06-25 14:27:15,791 - Rows processed: 2,120,000
# 2021-06-25 14:27:16,265 - Rows processed: 2,130,000
# 2021-06-25 14:27:16,724 - Rows processed: 2,140,000
# 2021-06-25 14:27:17,175 - Rows processed: 2,150,000
# 2021-06-25 14:27:17,593 - Rows processed: 2,160,000
# 2021-06-25 14:27:18,059 - Rows processed: 2,170,000
# 2021-06-25 14:27:18,569 - Rows processed: 2,180,000
# 2021-06-25 14:27:19,070 - Rows processed: 2,190,000
# 2021-06-25 14:27:20,190 - Rows processed: 2,200,000
# 2021-06-25 14:27:21,042 - Rows processed: 2,210,000
# 2021-06-25 14:27:21,505 - Rows processed: 2,220,000
# 2021-06-25 14:27:21,899 - Rows processed: 2,230,000
# 2021-06-25 14:27:22,341 - Rows processed: 2,240,000
# 2021-06-25 14:27:22,915 - Rows processed: 2,250,000
# 2021-06-25 14:27:23,647 - Rows processed: 2,260,000
# 2021-06-25 14:27:24,166 - Rows processed: 2,270,000
# 2021-06-25 14:27:24,739 - Rows processed: 2,280,000
# 2021-06-25 14:27:25,268 - Rows processed: 2,290,000
# 2021-06-25 14:27:25,776 - Rows processed: 2,300,000
# 2021-06-25 14:27:26,264 - Rows processed: 2,310,000
# 2021-06-25 14:27:35,153 - Rows processed: 2,320,000
# 2021-06-25 14:27:35,772 - Rows processed: 2,330,000
# 2021-06-25 14:27:36,301 - Rows processed: 2,340,000
# 2021-06-25 14:27:36,768 - Rows processed: 2,350,000
# 2021-06-25 14:27:37,244 - Rows processed: 2,360,000
# 2021-06-25 14:27:37,743 - Rows processed: 2,370,000
# 2021-06-25 14:27:38,233 - Rows processed: 2,380,000
# 2021-06-25 14:27:38,715 - Rows processed: 2,390,000
# 2021-06-25 14:27:39,290 - Rows processed: 2,400,000
# 2021-06-25 14:27:39,809 - Rows processed: 2,410,000
# 2021-06-25 14:27:40,310 - Rows processed: 2,420,000
# 2021-06-25 14:27:40,799 - Rows processed: 2,430,000
# 2021-06-25 14:27:41,351 - Rows processed: 2,440,000
# 2021-06-25 14:27:41,844 - Rows processed: 2,450,000
# 2021-06-25 14:27:42,373 - Rows processed: 2,460,000
# 2021-06-25 14:27:42,829 - Rows processed: 2,470,000
# 2021-06-25 14:27:43,277 - Rows processed: 2,480,000
# 2021-06-25 14:27:43,771 - Rows processed: 2,490,000
# 2021-06-25 14:27:44,234 - Rows processed: 2,500,000
# 2021-06-25 14:27:44,721 - Rows processed: 2,510,000
# 2021-06-25 14:27:45,259 - Rows processed: 2,520,000
# 2021-06-25 14:27:46,128 - Rows processed: 2,530,000
# 2021-06-25 14:27:46,720 - Rows processed: 2,540,000
# 2021-06-25 14:27:47,169 - Rows processed: 2,550,000
# 2021-06-25 14:27:47,635 - Rows processed: 2,560,000
# 2021-06-25 14:27:48,066 - Rows processed: 2,570,000
# 2021-06-25 14:27:48,552 - Rows processed: 2,580,000
# 2021-06-25 14:27:49,051 - Rows processed: 2,590,000
# 2021-06-25 14:27:49,567 - Rows processed: 2,600,000
# 2021-06-25 14:27:50,048 - Rows processed: 2,610,000
# 2021-06-25 14:27:50,531 - Rows processed: 2,620,000
# 2021-06-25 14:27:51,043 - Rows processed: 2,630,000
# 2021-06-25 14:27:51,599 - Rows processed: 2,640,000
# 2021-06-25 14:27:52,150 - Rows processed: 2,650,000
# 2021-06-25 14:27:52,792 - Rows processed: 2,660,000
# 2021-06-25 14:27:53,222 - Rows processed: 2,670,000
# 2021-06-25 14:27:53,653 - Rows processed: 2,680,000
# 2021-06-25 14:27:54,169 - Rows processed: 2,690,000
# 2021-06-25 14:27:54,658 - Rows processed: 2,700,000
# 2021-06-25 14:27:55,184 - Rows processed: 2,710,000
# 2021-06-25 14:27:55,720 - Rows processed: 2,720,000
# 2021-06-25 14:27:56,257 - Rows processed: 2,730,000
# 2021-06-25 14:34:04,203 - Rows processed: 5,620,000
# 2021-06-25 14:34:05,113 - Rows processed: 5,630,000
# 2021-06-25 14:34:05,840 - Rows processed: 5,640,000
# 2021-06-25 14:34:06,577 - Rows processed: 5,650,000
# 2021-06-25 14:34:07,393 - Rows processed: 5,660,000
# 2021-06-25 14:34:08,050 - Rows processed: 5,670,000
# 2021-06-25 14:34:08,977 - Rows processed: 5,680,000
# 2021-06-25 14:34:09,673 - Rows processed: 5,690,000
# 2021-06-25 14:34:10,328 - Rows processed: 5,700,000
# 2021-06-25 14:34:10,926 - Rows processed: 5,710,000
# 2021-06-25 14:34:11,503 - Rows processed: 5,720,000
# 2021-06-25 14:34:12,123 - Rows processed: 5,730,000
# 2021-06-25 14:34:13,064 - Rows processed: 5,740,000
# 2021-06-25 14:34:13,779 - Rows processed: 5,750,000
# 2021-06-25 14:34:14,349 - Rows processed: 5,760,000
# 2021-06-25 14:34:14,950 - Rows processed: 5,770,000

# %%
df
# Out:
#              reviewerID        asin                     reviewerName  helpful  \
# 0         ao94dhgc771sj  0528881469                          amazdnu      NaN
# 1         amo214lnfcei4  0528881469                  amazon customer      NaN
# 2        a3n7t0dy83y4ig  0528881469                    c. a. freeman      NaN
# 3        a1h8py3qhmqqa0  0528881469         dave m. shaw "mack dave"      NaN
# 4        a24ev6rxelqz63  0528881469                      wayne smith      NaN
# ...                 ...         ...                              ...      ...
# 1689183  a34bzm6s9l7qi4  b00lgq6hl8      candy cane "is it just me?"      NaN
# 1689184  a1g650tttheal5  b00lgq6hl8  charles spanky "zumina reviews"      NaN
# 1689185  a25c2m3qf9g7oq  b00lgq6hl8                           comdet      NaN
# 1689186   a1e1levq9vqnk  b00lgq6hl8                      j. chambers      NaN
# 1689187  a2nyk9kwfmjv4y  b00lgq6hl8      mike tarrani "jazz drummer"      NaN
#
#                                                 reviewText  overall  \
# 0        we got this gps for my husband who is an (otr)...      5.0
# 1        i'm a professional otr truck driver, and i bou...      1.0
# 2        well, what can i say.  i've had this unit in m...      3.0
# 3        not going to write a long review, even thought...      2.0
# 4        i've had mine for a year and here's what we go...      1.0
# ...                                                    ...      ...
# 1689183  burned these in before listening to them for a...      5.0
# 1689184  some people like dj style headphones or earbud...      5.0
# 1689185  i&#8217;m a big fan of the brainwavz s1 (actua...      5.0
# 1689186  i've used thebrainwavz s1 in ear headphones, a...      5.0
# 1689187  normally when i receive a review sample i can ...      5.0
#
#                                                    summary  unixReviewTime  \
# 0                                          gotta have gps!      1370131200
# 1                                        very disappointed      1290643200
# 2                                           1st impression      1283990400
# 3                                  great grafics, poor gps      1290556800
# 4                   major issues, only excuses for support      1317254400
# ...                                                    ...             ...
# 1689183                boom -- pop -- pow.  these deliver.      1405555200
# 1689184  thin and light, without compromising on sound ...      1405382400
# 1689185  same form factor and durability as the s1 with...      1405555200
# 1689186  superb audio quality in a very comfortable set...      1405641600
# 1689187                                  exceptional sound      1405209600
#
#           reviewTime
# 0         06 2, 2013
# 1        11 25, 2010
# 2         09 9, 2010
# 3        11 24, 2010
# 4        09 29, 2011
# ...              ...
# 1689183  07 17, 2014
# 1689184  07 15, 2014
# 1689185  07 17, 2014
# 1689186  07 18, 2014
# 1689187  07 13, 2014
#
# [1689188 rows x 9 columns]

# %%
df.to_csv(write_books, index=False)

# %%
# !ls -lah data/
# Out:
# total 24809632
# drwxr-xr-x   6 rsilvei  813930708   192B Jun 25 14:09 .
# drwxr-xr-x  11 rsilvei  813930708   352B Jun 25 14:10 ..
# -rw-r--r--   1 rsilvei  813930708   1.2G Jun 25 14:10 books.csv
# -rw-r--r--   1 rsilvei  813930708   8.8G Jun 10 19:01 reviews_Books_5.json
# -rw-r--r--   1 rsilvei  813930708   1.4G Jun 10 18:37 reviews_Electronics_5.json
# -rw-r--r--@  1 rsilvei  813930708   473M Jun 25 13:59 reviews_Electronics_5.json.gz

# %%
def get_category_lvl(category_list: list, lvl=0) -> str:
    try:
        return category_list[lvl]
    except IndexError:
        return 'NA_VALUE'


def get_categories(df: pd.DataFrame) -> pd.DataFrame:
    df['category_lvl_1'] = df['categories'].apply(get_category_lvl, args=(0,))
    df['category_lvl_2'] = df['categories'].apply(get_category_lvl, args=(1,))
    df['category_lvl_3'] = df['categories'].apply(get_category_lvl, args=(2,))
    df['category_lvl_4'] = df['categories'].apply(get_category_lvl, args=(3,))
    logger.info('Categories lvl 1 - 4 prepared')

    return df


def get_meta(df: pd.DataFrame) -> pd.DataFrame:
    # Update to reflect if relationship exist
    df['related'] = np.where(df['related'].isnull(), 0, 1)

    # Prep categories
    df['categories'] = df['categories'].apply(eval)
    df['categories'] = df['categories'].apply(lambda x: x[0])  # Get first category only
    df = get_categories(df)

    # Prep title and description
    # TODO: Add cleaning of title and description

    return df

# %%
META_COLS = ['asin', 'categories', 'title', 'description', 'price', 'brand', 'related']
df = pd.read_csv(write_books, error_bad_lines=False, warn_bad_lines=True,
                 dtype={'asin': 'str', 'title': 'str', 'brand': 'str'},
                 usecols=META_COLS)
logger.info('DF shape: {}'.format(df.shape))

meta_df = get_meta(df)

meta_df.to_csv(args.write_path, index=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-1df6f605f328> in <module>
#       2 df = pd.read_csv(write_books, error_bad_lines=False, warn_bad_lines=True,
#       3                  dtype={'asin': 'str', 'title': 'str', 'brand': 'str'},
# ----> 4                  usecols=META_COLS)
#       5 logger.info('DF shape: {}'.format(df.shape))
#       6
#
# ~/.pyenv/versions/3.7.2/envs/torch/lib/python3.7/site-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     608     kwds.update(kwds_defaults)
#     609
# --> 610     return _read(filepath_or_buffer, kwds)
#     611
#     612
#
# ~/.pyenv/versions/3.7.2/envs/torch/lib/python3.7/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     460
#     461     # Create the parser.
# --> 462     parser = TextFileReader(filepath_or_buffer, **kwds)
#     463
#     464     if chunksize or iterator:
#
# ~/.pyenv/versions/3.7.2/envs/torch/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     817             self.options["has_index_names"] = kwds["has_index_names"]
#     818
# --> 819         self._engine = self._make_engine(self.engine)
#     820
#     821     def close(self):
#
# ~/.pyenv/versions/3.7.2/envs/torch/lib/python3.7/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1048             )
#    1049         # error: Too many arguments for "ParserBase"
# -> 1050         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1051
#    1052     def _failover_to_python(self):
#
# ~/.pyenv/versions/3.7.2/envs/torch/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1947                 self.orig_names
#    1948             ):
# -> 1949                 _validate_usecols_names(usecols, self.orig_names)
#    1950
#    1951             if len(self.names) > len(usecols):
#
# ~/.pyenv/versions/3.7.2/envs/torch/lib/python3.7/site-packages/pandas/io/parsers.py in _validate_usecols_names(usecols, names)
#    1161     if len(missing) > 0:
#    1162         raise ValueError(
# -> 1163             f"Usecols do not match columns, columns expected but not found: {missing}"
#    1164         )
#    1165
#
# ValueError: Usecols do not match columns, columns expected but not found: ['description', 'title', 'categories', 'price', 'related', 'brand']
